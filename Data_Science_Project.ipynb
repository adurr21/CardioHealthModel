# %%
import pandas as pd

# %%
df = pd.read_csv("LLCP2022.csv")

# %%
df
# Out:
#        General Health                  Checkup Skin Cancer Other Cancer  \
# 2           Very Good     Within the past year         Yes           No
# 4                Fair     Within the past year          No           No
# 5                Poor     Within the past year          No           No
# 6           Very Good     Within the past year          No           No
# 7                Good     Within the past year          No          Yes
# ...               ...                      ...         ...          ...
# 445126           Good  Within the past 2 years          No           No
# 445127           Good  Within the past 2 years          No           No
# 445128      Excellent     Within the past year          No           No
# 445129           Poor      5 or more years ago          No           No
# 445130      Very Good     Within the past year          No           No
#
#        Depression Diabetes Smoking History  Alcohol Consumption Exercise  \
# ...

# %%
df["Checkup"]
# Out:
# 0            Within the past year
# 1                             NaN
# 2            Within the past year
# 3            Within the past year
# 4            Within the past year
#                    ...
# 445127    Within the past 2 years
# 445128       Within the past year
# 445129        5 or more years ago
# 445130       Within the past year
# 445131                        NaN
# Name: Checkup, Length: 445132, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   General Health       443934 non-null  object
#  1   Checkup              436824 non-null  object
#  2   Skin Cancer          441989 non-null  object
#  3   Other Cancer         442711 non-null  object
#  4   Depression           442320 non-null  object
#  5   Diabetes             444045 non-null  object
#  6   Smoking History      410172 non-null  object
#  7   Alcohol Consumption  445132 non-null  int64
#  8   Exercise             444039 non-null  object
#  9   Heart Disease        440111 non-null  object
#  10  Arthritis            442499 non-null  object
#  11  Sex                  445132 non-null  object
#  12  Age                  436053 non-null  object
#  13  Height (cm)          416480 non-null  float64
#  14  Weight (g)           445132 non-null  int64
# ...

# %%
def uniqueValues(col):
    return list(df[col].unique())

for col in df.select_dtypes('object').columns:
    print(f'{col}\n{uniqueValues(col)}\n')
# Out:
# General Health
# ['Very Good', 'Excellent', 'Fair', 'Poor', 'Good']
#
# Checkup
# ['Within the past year', nan, 'Within the past 2 years', 'Within the past 5 years', '5 or more years ago']
#
# Skin Cancer
# ['No', 'Yes', nan]
#
# Other Cancer
# ['No', 'Yes', nan]
#
# Depression
# ['No', 'Yes', nan]
#
# Diabetes
# ['Yes', 'No', 'No, prediabetes or\nborderline\ndiabetes', nan, 'Yes, but\nfemale told\nonly during\npregnancy']
#
# Smoking History
# ['No', 'Yes', nan]
#
# Exercise
# ['No', 'Yes', nan]
#
# Heart Disease
# ['No', 'Yes', nan]
#
# Arthritis
# ['No', 'Yes', nan]
#
# Sex
# ['Female', 'Male']
#
# Age
# ['80+', '55 to 59', nan, '40 to 44', '75 to 79', '70 to 74', '65 to 69', '60 to 64', '50 to 54', '45 to 49', '35 to 39', '25 to 29', '30 to 34', '18 to 24']

# %%
df.dropna(subset=["_BMI5"], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389569 entries, 0 to 445131
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   General Health       389569 non-null  object
#  1   Checkup              383223 non-null  object
#  2   Skin Cancer          389569 non-null  object
#  3   Other Cancer         389569 non-null  object
#  4   Depression           389569 non-null  object
#  5   Diabetes             389569 non-null  object
#  6   Smoking History      389569 non-null  object
#  7   Alcohol Consumption  389569 non-null  int64
#  8   Exercise             389569 non-null  object
#  9   Heart Disease        389569 non-null  object
#  10  Arthritis            389569 non-null  object
#  11  Sex                  389569 non-null  object
#  12  Age                  389569 non-null  object
#  13  Height (cm)          382098 non-null  float64
#  14  Weight (g)           389569 non-null  int64
# ...
